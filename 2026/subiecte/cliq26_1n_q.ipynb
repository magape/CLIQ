# %% [markdown]
# # Subiecte CLIQ 2026, categoria Novice
#
# * **Timp de lucru:** 3 ore
# * **Total punctaj:** 100 puncte (10 puncte din oficiu)

# %% [markdown]
# ## Pasul 0: Pregătirea mediului de lucru (instalare Qiskit)

# %%
#@markdown Rulați această celulă pentru a instala Qiskit și simulatoarele necesare în Google Colab. Această operațiune durează aproximativ 30 de secunde și trebuie rulată o singură dată la începutul sesiunii.

# !pip install qiskit qiskit-aer pylatexenc matplotlib -q
print("✅ Mediul cuantic CLIQ 2026 a fost configurat cu succes! Qiskit este gata de utilizare.")
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.8/9.8 MB 55.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.4/12.4 MB 75.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 137.5/137.5 kB 8.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 76.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.9/54.9 kB 4.1 MB/s eta 0:00:00
# ✅ Mediul cuantic CLIQ 2026 a fost configurat cu succes! Qiskit este gata de utilizare.

# %% [markdown]
# ## Partea I: Logică clasică și cuantică (45 de puncte)

# %% [markdown]
# ### Subiectul 1: Tabele de adevăr și circuite logice (20 de puncte)
# Un circuit logic clasic primește două intrări binare $A$ și $B$ ($A, B \in \{0, 1\}$) și procesează semnalele prin următoarea cascadă de porți logice:
# 1. $C = \text{NOT}(A)$
# 2. $D = A \text{ AND } B$
# 3. $F = C \text{ OR } D$
#
# **Cerințe:**
# 1. **[10 puncte]** Construiți tabelul de adevăr complet pentru intrările $A$ și $B$, incluzând coloane pentru stările intermediare $C$ și $D$, precum și pentru ieșirea finală $F$ (pentru toate cele 4 combinații posibile).
# 2. **[10 puncte]** Exprimați funcția logică finală $F(A, B)$ sub formă de expresie booleană și simplificați-o la maximum folosind legile algebrei booleene (distributivitatea, legile lui De Morgan, complementaritarea etc.). Explicați fiecare pas al simplificării.

# %% [markdown]
# ### Subiectul 1 - Răspuns
# *Dați dublu clic (sau apăsați pe Enter) pentru a edita răspunsul.*

# %% [markdown]
# ### Subiectul 2: Sfera Bloch și rotirea qubiților (25 de puncte)
# Un qubit este inițializat în starea computațională pură $|0\rangle$ (corespunzătoare Polului Nord pe Sfera Bloch). Asupra acestui qubit se aplică succesiv următoarele transformări cuantice:
# 1. O poartă Pauli-X (NOT cuantic).
# 2. O poartă Hadamard ($H$).
#
# **Cerințe:**
# 1. **[10 puncte]** Scrieți expresia matematică exactă a stării qubitului după fiecare dintre cele două transformări, folosind formalismul Dirac bra-ket (amplitudini de probabilitate).
# 2. **[10 puncte]** Care este probabilitatea teoretică de a măsura starea $|1\rangle$ la finalul întregii secvențe de porți? Justificați răspunsul calculând probabilitatea pe baza amplitudinii de probabilitate corespunzătoare.
# 3. **[5 puncte]** Unde se poziționează starea finală a qubitului pe Sfera Bloch? Specificați axa și coordonatele geometrice tridimensionale exacte $(x, y, z)$.

# %% [markdown]
# ### Subiectul 2 - Răspuns
# *Dați dublu clic (sau apăsați pe Enter) pentru a edita răspunsul.*

# %% [markdown]
# ## Partea II: Programare în Qiskit (45 de puncte)

# %% [markdown]
# ### Subiectul 3: Generarea și măsurarea stării de superpoziție |+⟩ (45 de puncte)
# În acest subiect, veți scrie și simula un algoritm cuantic simplu care generează o stare de superpoziție simetrică pe un singur qubit.
#
# **Cerințe:**
# 1. **[10 puncte]** Creați un circuit cuantic în Qiskit format dintr-un registru cuantic cu un singur qubit ($q_0$) și un registru clasic cu un singur bit ($c_0$).
# 2. **[10 puncte]** Aplicați poarta cuantică potrivită pentru a plasa qubitul $q_0$ în starea de superpoziție simetrică $|+\rangle = \frac{|0\rangle + |1\rangle}{\sqrt{2}}$.
# 3. **[10 puncte]** Adăugați operația de măsurătoare a qubitului cuantic $q_0$ în registrul clasic $c_0$.
# 4. **[15 puncte]** Simulați rularea acestui circuit pentru un număr de $N = 1024$ de rulări (shots) utilizând simulatorul local standard `AerSimulator`.
#    * Extrageți dicționarul de rezultate (numărul de apariții pentru stările $0$ și $1$).
#    * Explicați de ce numărul de apariții obținut la rulare nu este exact 512 pentru $0$ și 512 pentru $1$ (conectând fenomenul cu caracterul probabilistic al măsurătorii și fluctuațiile statistice Monte Carlo).

# %% [markdown]
# ### Subiectul 3 - Răspuns
# * Scrieți codul vostru în celula Python de mai jos.
# * Redactați răspunsul teoretic (colapsul funcției de undă și analiza fluctuațiilor statistice) în celula Markdown care urmează imediat după celula de cod Python.

# %%
# Scrie în această celulă programul pentru Subiectul 3

# 0. Importarea bibliotecilor necesare din Qiskit (QuantumCircuit și AerSimulator)


# 1. Inițializarea circuitului cuantic cu 1 qubit și 1 bit clasic


# 2. Aplicarea poartei logice potrivite pentru a genera superpoziția


# 3. Adăugarea măsurătorii qubitului în registrul clasic


# 4. Instanțierea simulatorului, rularea cu shots=1024 și extragerea dicționarului de counts

# %% [markdown]
# **Justificarea teoretică pentru Subiectul 3**
#
# *Dați dublu clic (sau apăsați pe Enter) pentru a edita răspunsul.*
